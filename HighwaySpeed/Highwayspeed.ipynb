# %%
def Speed(Fclass,StateCode):
	if(Fclass ==1 and StateCode ==42):
		return 70
	elif(Fclass ==1 and StateCode ==39):
		return 70
	elif(Fclass ==1 and StateCode ==36):
		return 65
	elif(Fclass ==1):
		return 70
	elif(Fclass ==2 and StateCode ==42):
		return 55
	elif(Fclass ==2 and StateCode ==39):
		return 60
	elif(Fclass ==2 and StateCode ==36):
		return 55
	elif(Fclass ==2):
		return 60
	elif(Fclass ==6 and StateCode ==42):
		return 50
	elif(Fclass ==6 and StateCode ==39):
		return 55
	elif(Fclass ==6 and StateCode ==36):
		return 50
	elif(Fclass ==6):
		return 55
	elif(Fclass ==7 and StateCode ==42):
		return 45
	elif(Fclass ==7 and StateCode ==39):
		return 50
	elif(Fclass ==7 and StateCode ==36):
		return 45
	elif(Fclass ==7):
		return 50
	elif(Fclass ==8 and StateCode ==42):
		return 40
	elif(Fclass ==8 and StateCode ==39):
		return 45
	elif(Fclass ==8 and StateCode ==36):
		return 40
	elif(Fclass ==8):
		return 45
	elif(Fclass ==9 and StateCode ==42):
		return 25
	elif(Fclass ==9 and StateCode ==39):
		return 30
	elif(Fclass ==9 and StateCode ==36):
		return 30
	elif(Fclass ==9):
		return 30
	elif(Fclass ==11 and StateCode ==42):
		return 55
	elif(Fclass ==11 and StateCode ==39):
		return 60
	elif(Fclass ==11 and StateCode ==36):
		return 55
	elif(Fclass ==11):
		return 60
	elif(Fclass ==12 and StateCode ==42):
		return 55
	elif(Fclass ==12 and StateCode ==39):
		return 60
	elif(Fclass ==12 and StateCode ==36):
		return 55
	elif(Fclass ==12):
		return 60
	elif(Fclass ==14 and StateCode ==42):
		return 45
	elif(Fclass ==14 and StateCode ==39):
		return 50
	elif(Fclass ==14 and StateCode ==36):
		return 45
	elif(Fclass ==14):
		return 50
	elif(Fclass ==16 and StateCode ==42):
		return 40
	elif(Fclass ==16 and StateCode ==39):
		return 45
	elif(Fclass ==16 and StateCode ==36):
		return 40
	elif(Fclass ==16):
		return 45
	elif(Fclass ==17 and StateCode ==42):
		return 35
	elif(Fclass ==17 and StateCode ==39):
		return 40
	elif(Fclass ==17 and StateCode ==36):
		return 35
	elif(Fclass ==17):
		return 40
	elif(Fclass ==19 and StateCode ==42):
		return 25
	elif(Fclass ==19 and StateCode ==39):
		return 30
	elif(Fclass ==19 and StateCode ==36):
		return 30
	elif(Fclass ==19):
		return 30
	else:
		return 45
